# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "datasets/"

# List all the .txt files and sort them alphabetically
files = glob.glob(f"{folder}*.txt")
# ... YOUR CODE FOR TASK 1 ...
files
# Out:
# ['datasets\\Autobiography.txt',
#  'datasets\\CoralReefs.txt',
#  'datasets\\DescentofMan.txt',
#  'datasets\\DifferentFormsofFlowers.txt',
#  'datasets\\EffectsCrossSelfFertilization.txt',
#  'datasets\\ExpressionofEmotionManAnimals.txt',
#  'datasets\\FormationVegetableMould.txt',
#  'datasets\\FoundationsOriginofSpecies.txt',
#  'datasets\\GeologicalObservationsSouthAmerica.txt',
#  'datasets\\InsectivorousPlants.txt',
#  'datasets\\LifeandLettersVol1.txt',
#  'datasets\\LifeandLettersVol2.txt',
#  'datasets\\MonographCirripedia.txt',
#  'datasets\\MonographCirripediaVol2.txt',
#  'datasets\\MovementClimbingPlants.txt',
#  'datasets\\OriginofSpecies.txt',
#  'datasets\\PowerMovementPlants.txt',
#  'datasets\\VariationPlantsAnimalsDomestication.txt',
#  'datasets\\VolcanicIslands.txt',
#  'datasets\\VoyageBeagle.txt']

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
books = []
titles = []

for file in files:
    title = file.strip(".txt").split('\\')[-1]
    # Open each file
    text = open(file, encoding='utf-8-sig').read()
    # Remove all non-alpha-numeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]+', '', text)
    # Store the texts and titles of the books in two separate lists
    books.append(text)
    titles.append(title)
    print(f"{title:50s} : {len(text):5d} words")
# Out:
# Autobiography                                      : 123229 words
# CoralReefs                                         : 496539 words
# DescentofMan                                       : 1785723 words
# DifferentFormsofFlowers                            : 616671 words
# EffectsCrossSelfFertilization                      : 919542 words
# ExpressionofEmotionManAnimals                      : 624250 words
# FormationVegetableMould                            : 342689 words
# FoundationsOriginofSpecies                         : 534797 words
# GeologicalObservationsSouthAmerica                 : 796499 words
# InsectivorousPlants                                : 904003 words
# LifeandLettersVol1                                 : 1047646 words
# LifeandLettersVol2                                 : 1014384 words
# MonographCirripedia                                : 777741 words
# MonographCirripediaVol2                            : 1723333 words
# MovementClimbingPlants                             : 305219 words
# OriginofSpecies                                    : 919177 words
# PowerMovementPlants                                : 1094855 words
# VariationPlantsAnimalsDomestication                : 1084841 words
# VolcanicIslands                                    : 341193 words
# VoyageBeagle                                       : 1154047 words

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
index = -1
# Browse the list containing all the titles
for i,t in enumerate(titles):
    # Store the index if the title is "OriginofSpecies"
    if t == "OriginofSpecies":
        index = i
        

# Print the stored index
index
# Out:
# 15

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Transform the text into tokens 
books_split = [b.lower().split() for b in books]

# Remove tokens which are part of the list of stop words
books_tokens = [[t for t in book if t not in stoplist] for book in books_split]

# Print the first 20 tokens for the "On the Origin of Species" book
books_tokens[index][:20]
# Out:
# ['on',
#  'origin',
#  'species',
#  'but',
#  'with',
#  'regard',
#  'material',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'thiswe',
#  'can',
#  'perceive',
#  'events',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
# import pickle

# # Load the stemmed tokens list from the pregenerated pickle file
# texts_stem = pickle.load(open("datasets/texts_stem.p","rb"))

# # Print the 20 first stemmed tokens from the "On the Origin of Species" book
# texts_stem

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

books_stem = [[stemmer.stem(word) for word in book] for book in books_tokens]

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(books_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(book_stem, allow_update=True) for book_stem in books_stem]

# Print the first five elements of the On the Origin of species' BoW model
bows[index][:10]
# Out:
# [(0, 3),
#  (5, 4),
#  (6, 1),
#  (8, 2),
#  (22, 1),
#  (24, 2),
#  (28, 1),
#  (29, 3),
#  (36, 1),
#  (37, 1)]

# %%
dictionary[779]
# Out:
# 'draw'

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
# Import pandas to create and manipulate DataFrames
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df = pd.DataFrame(bows[index])

# Add the column names to the DataFrame
df.columns = ["Id", "Count"]

df.head()
# Add a column containing the token corresponding to the dictionary index
df["Token"] = df["Id"].apply(lambda t:dictionary[t])

# Sort the DataFrame by descending number of occurrences and print the first 10 values
df.sort_values(by=["Count"], ascending=False)
# Out:
#          Id  Count       Token
# 730    1194   2022        have
# 1090   1778   1520          on
# 870    1394   1468          it
# 1461   2340   1465       speci
# 231     401   1357          by
# ...     ...    ...         ...
# 3177   7461      1    buckland
# 2243   3979      1      ellipt
# 4412  16703      1  intermingl
# 4411  16702      1  intermedia
# 2694   5566      1   suspicion
#
# [5882 rows x 3 columns]

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
model[bows[index]]
# Out:
# [(8, 0.00020097437165053156),
#  (22, 0.0005635894948497614),
#  (24, 0.0016878683054617335),
#  (28, 0.0003183860592999839),
#  (29, 0.0025318024581926003),
#  (36, 0.0010007434693478996),
#  (37, 0.0010007434693478996),
#  (53, 0.0008743079489962759),
#  (56, 0.0020014869386957993),
#  (58, 0.0027158485478012808),
#  (65, 0.0023424098025074612),
#  (2484, 0.00010048718582526578),
#  (2485, 0.002064086902970208),
#  (2495, 0.0005635894948497614),
#  (2497, 0.02869080795128589),
#  (2500, 0.004692998892592983),
#  (2506, 0.0034972317959851037),
#  (2509, 0.0005024359291263289),
#  (2510, 0.0006192260708910624),
#  (2511, 0.0014448608320791457),
#  (2516, 0.0016512695223761663),
#  (2520, 0.013690600549899307),
#  (2529, 0.0020566756759842386),
#  (2530, 0.0011712049012537306),
#  (2531, 0.0011271789896995228),
#  (2532, 0.0075954073745778),
#  (2533, 0.0015073077873789867),
#  (2536, 0.0002064086902970208),
#  (2540, 0.0016512695223761663),
#  (2541, 0.0054316970956025615),
#  ...]

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame(model[bows[index]])

# Name the columns of the DataFrame id and score
df_tfidf.columns = ["Id", "Score"]

# Add the tokens corresponding to the numerical indices for better readability
df_tfidf["Token"] = df_tfidf["Id"].apply(lambda t:dictionary[t])

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
df_tfidf = df_tfidf.sort_values(by=["Score"], ascending=False)
df_tfidf.head(10)
# Out:
#          Id     Score    Token
# 863    2214  0.306752   select
# 122     376  0.209155    breed
# 3040  10860  0.156172   migrat
# 3164  11698  0.150137   pigeon
# 932    2377  0.142106   steril
# 276     765  0.138353   domest
# 3980  21051  0.122648   grtner
# 364     985  0.119839   fertil
# 491    1282  0.118089   hybrid
# 423    1116  0.117231  glacial

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities

# Compute the similarity matrix (pairwise distance between all texts)
sims = similarities.MatrixSimilarity(bows)

# Transform the resulting list into a dataframe
sim_df = pd.DataFrame(sims)

# Add the titles of the books as columns and index of the dataframe
sim_df.columns = titles
sim_df.index = titles

# Print the resulting matrix
sim_df
# Out:
#                                      Autobiography  CoralReefs  DescentofMan  \
# Autobiography                             1.000000    0.611831      0.672806
# CoralReefs                                0.611831    1.000000      0.686506
# DescentofMan                              0.672806    0.686506      1.000000
# DifferentFormsofFlowers                   0.539330    0.568523      0.627168
# EffectsCrossSelfFertilization             0.468792    0.439073      0.492848
# ExpressionofEmotionManAnimals             0.727547    0.684927      0.817775
# FormationVegetableMould                   0.723301    0.686693      0.701021
# FoundationsOriginofSpecies                0.661286    0.694670      0.815597
# GeologicalObservationsSouthAmerica        0.659816    0.778307      0.713631
# InsectivorousPlants                       0.644393    0.586193      0.621761
# LifeandLettersVol1                        0.892982    0.627532      0.682546
# LifeandLettersVol2                        0.812473    0.624705      0.684554
# MonographCirripedia                       0.556707    0.654714      0.710401
# MonographCirripediaVol2                   0.573036    0.681645      0.717647
# MovementClimbingPlants                    0.624748    0.609508      0.655143
# OriginofSpecies                           0.686142    0.730133      0.838162
# PowerMovementPlants                       0.684432    0.621631      0.649038
# VariationPlantsAnimalsDomestication       0.696499    0.719714      0.858421
# VolcanicIslands                           0.655968    0.807210      0.739277
# VoyageBeagle                              0.830519    0.797567      0.791111
#
#                                      DifferentFormsofFlowers  \
# Autobiography                                       0.539330
# CoralReefs                                          0.568523
# DescentofMan                                        0.627168
# DifferentFormsofFlowers                             1.000000
# EffectsCrossSelfFertilization                       0.743533
# ExpressionofEmotionManAnimals                       0.594050
# FormationVegetableMould                             0.590192
# FoundationsOriginofSpecies                          0.650668
# GeologicalObservationsSouthAmerica                  0.595610
# InsectivorousPlants                                 0.568156
# LifeandLettersVol1                                  0.523907
# LifeandLettersVol2                                  0.523534
# MonographCirripedia                                 0.597627
# MonographCirripediaVol2                             0.604634
# MovementClimbingPlants                              0.609511
# OriginofSpecies                                     0.689501
# PowerMovementPlants                                 0.610582
# VariationPlantsAnimalsDomestication                 0.699729
# VolcanicIslands                                     0.618968
# VoyageBeagle                                        0.646935
#
#                                      EffectsCrossSelfFertilization  \
# Autobiography                                             0.468792
# CoralReefs                                                0.439073
# DescentofMan                                              0.492848
# DifferentFormsofFlowers                                   0.743533
# EffectsCrossSelfFertilization                             1.000000
# ExpressionofEmotionManAnimals                             0.478126
# FormationVegetableMould                                   0.518551
# FoundationsOriginofSpecies                                0.523135
# GeologicalObservationsSouthAmerica                        0.480605
# InsectivorousPlants                                       0.510855
# LifeandLettersVol1                                        0.434003
# LifeandLettersVol2                                        0.435369
# MonographCirripedia                                       0.448209
# MonographCirripediaVol2                                   0.461005
# MovementClimbingPlants                                    0.534952
# OriginofSpecies                                           0.566155
# PowerMovementPlants                                       0.565378
# VariationPlantsAnimalsDomestication                       0.575229
# VolcanicIslands                                           0.480384
# VoyageBeagle                                              0.538932
#
#                                      ExpressionofEmotionManAnimals  \
# Autobiography                                             0.727547
# CoralReefs                                                0.684927
# DescentofMan                                              0.817775
# DifferentFormsofFlowers                                   0.594050
# EffectsCrossSelfFertilization                             0.478126
# ExpressionofEmotionManAnimals                             1.000000
# FormationVegetableMould                                   0.734087
# FoundationsOriginofSpecies                                0.778382
# GeologicalObservationsSouthAmerica                        0.719997
# InsectivorousPlants                                       0.645529
# LifeandLettersVol1                                        0.746087
# LifeandLettersVol2                                        0.714918
# MonographCirripedia                                       0.692138
# MonographCirripediaVol2                                   0.723117
# MovementClimbingPlants                                    0.713830
# OriginofSpecies                                           0.790023
# PowerMovementPlants                                       0.701498
# VariationPlantsAnimalsDomestication                       0.815230
# VolcanicIslands                                           0.754096
# VoyageBeagle                                              0.826773
#
#                                      FormationVegetableMould  \
# Autobiography                                       0.723301
# CoralReefs                                          0.686693
# DescentofMan                                        0.701021
# DifferentFormsofFlowers                             0.590192
# EffectsCrossSelfFertilization                       0.518551
# ExpressionofEmotionManAnimals                       0.734087
# FormationVegetableMould                             1.000000
# FoundationsOriginofSpecies                          0.682352
# GeologicalObservationsSouthAmerica                  0.750594
# InsectivorousPlants                                 0.720394
# LifeandLettersVol1                                  0.672207
# LifeandLettersVol2                                  0.633769
# MonographCirripedia                                 0.653874
# MonographCirripediaVol2                             0.674419
# MovementClimbingPlants                              0.682889
# OriginofSpecies                                     0.721081
# PowerMovementPlants                                 0.754896
# VariationPlantsAnimalsDomestication                 0.742557
# VolcanicIslands                                     0.761638
# VoyageBeagle                                        0.836069
#
#                                      FoundationsOriginofSpecies  \
# Autobiography                                          0.661286
# CoralReefs                                             0.694670
# DescentofMan                                           0.815597
# DifferentFormsofFlowers                                0.650668
# EffectsCrossSelfFertilization                          0.523135
# ExpressionofEmotionManAnimals                          0.778382
# FormationVegetableMould                                0.682352
# FoundationsOriginofSpecies                             1.000000
# GeologicalObservationsSouthAmerica                     0.719274
# InsectivorousPlants                                    0.607435
# LifeandLettersVol1                                     0.706665
# LifeandLettersVol2                                     0.703349
# MonographCirripedia                                    0.676734
# MonographCirripediaVol2                                0.717676
# MovementClimbingPlants                                 0.677890
# OriginofSpecies                                        0.908244
# PowerMovementPlants                                    0.656304
# VariationPlantsAnimalsDomestication                    0.857159
# VolcanicIslands                                        0.740283
# VoyageBeagle                                           0.794574
#
#                                      GeologicalObservationsSouthAmerica  \
# Autobiography                                                  0.659816
# CoralReefs                                                     0.778307
# DescentofMan                                                   0.713631
# DifferentFormsofFlowers                                        0.595610
# EffectsCrossSelfFertilization                                  0.480605
# ExpressionofEmotionManAnimals                                  0.719997
# FormationVegetableMould                                        0.750594
# FoundationsOriginofSpecies                                     0.719274
# GeologicalObservationsSouthAmerica                             1.000000
# InsectivorousPlants                                            0.633833
# LifeandLettersVol1                                             0.651500
# LifeandLettersVol2                                             0.638847
# MonographCirripedia                                            0.704746
# MonographCirripediaVol2                                        0.738296
# MovementClimbingPlants                                         0.651970
# OriginofSpecies                                                0.763107
# PowerMovementPlants                                            0.674519
# VariationPlantsAnimalsDomestication                            0.765187
# VolcanicIslands                                                0.899808
# VoyageBeagle                                                   0.843135
#
#                                      InsectivorousPlants  LifeandLettersVol1  \
# Autobiography                                   0.644393            0.892982
# CoralReefs                                      0.586193            0.627532
# DescentofMan                                    0.621761            0.682546
# DifferentFormsofFlowers                         0.568156            0.523907
# EffectsCrossSelfFertilization                   0.510855            0.434003
# ExpressionofEmotionManAnimals                   0.645529            0.746087
# FormationVegetableMould                         0.720394            0.672207
# FoundationsOriginofSpecies                      0.607435            0.706665
# GeologicalObservationsSouthAmerica              0.633833            0.651500
# InsectivorousPlants                             0.999999            0.592103
# LifeandLettersVol1                              0.592103            1.000000
# LifeandLettersVol2                              0.560476            0.957262
# MonographCirripedia                             0.604018            0.571518
# MonographCirripediaVol2                         0.607010            0.600524
# MovementClimbingPlants                          0.682693            0.623751
# OriginofSpecies                                 0.630588            0.728325
# PowerMovementPlants                             0.748059            0.634634
# VariationPlantsAnimalsDomestication             0.649481            0.708267
# VolcanicIslands                                 0.640564            0.658068
# VoyageBeagle                                    0.738004            0.813076
#
#                                      LifeandLettersVol2  MonographCirripedia  \
# Autobiography                                  0.812473             0.556707
# CoralReefs                                     0.624705             0.654714
# DescentofMan                                   0.684554             0.710401
# DifferentFormsofFlowers                        0.523534             0.597627
# EffectsCrossSelfFertilization                  0.435369             0.448209
# ExpressionofEmotionManAnimals                  0.714918             0.692138
# FormationVegetableMould                        0.633769             0.653874
# FoundationsOriginofSpecies                     0.703349             0.676734
# GeologicalObservationsSouthAmerica             0.638847             0.704746
# InsectivorousPlants                            0.560476             0.604018
# LifeandLettersVol1                             0.957262             0.571518
# LifeandLettersVol2                             1.000000             0.556418
# MonographCirripedia                            0.556418             1.000000
# MonographCirripediaVol2                        0.594544             0.906069
# MovementClimbingPlants                         0.603831             0.648544
# OriginofSpecies                                0.733709             0.704912
# PowerMovementPlants                            0.599234             0.642731
# VariationPlantsAnimalsDomestication            0.698020             0.740972
# VolcanicIslands                                0.648714             0.715577
# VoyageBeagle                                   0.755466             0.726851
#
#                                      MonographCirripediaVol2  \
# Autobiography                                       0.573036
# CoralReefs                                          0.681645
# DescentofMan                                        0.717647
# DifferentFormsofFlowers                             0.604634
# EffectsCrossSelfFertilization                       0.461005
# ExpressionofEmotionManAnimals                       0.723117
# FormationVegetableMould                             0.674419
# FoundationsOriginofSpecies                          0.717676
# GeologicalObservationsSouthAmerica                  0.738296
# InsectivorousPlants                                 0.607010
# LifeandLettersVol1                                  0.600524
# LifeandLettersVol2                                  0.594544
# MonographCirripedia                                 0.906069
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.670283
# OriginofSpecies                                     0.746749
# PowerMovementPlants                                 0.653343
# VariationPlantsAnimalsDomestication                 0.767674
# VolcanicIslands                                     0.747256
# VoyageBeagle                                        0.744307
#
#                                      MovementClimbingPlants  OriginofSpecies  \
# Autobiography                                      0.624748         0.686142
# CoralReefs                                         0.609508         0.730133
# DescentofMan                                       0.655143         0.838162
# DifferentFormsofFlowers                            0.609511         0.689501
# EffectsCrossSelfFertilization                      0.534952         0.566155
# ExpressionofEmotionManAnimals                      0.713830         0.790023
# FormationVegetableMould                            0.682889         0.721081
# FoundationsOriginofSpecies                         0.677890         0.908244
# GeologicalObservationsSouthAmerica                 0.651970         0.763107
# InsectivorousPlants                                0.682693         0.630588
# LifeandLettersVol1                                 0.623751         0.728325
# LifeandLettersVol2                                 0.603831         0.733709
# MonographCirripedia                                0.648544         0.704912
# MonographCirripediaVol2                            0.670283         0.746749
# MovementClimbingPlants                             1.000000         0.698977
# OriginofSpecies                                    0.698977         1.000000
# PowerMovementPlants                                0.773696         0.666128
# VariationPlantsAnimalsDomestication                0.708203         0.876347
# VolcanicIslands                                    0.672252         0.777222
# VoyageBeagle                                       0.751101         0.817594
#
#                                      PowerMovementPlants  \
# Autobiography                                   0.684432
# CoralReefs                                      0.621631
# DescentofMan                                    0.649038
# DifferentFormsofFlowers                         0.610582
# EffectsCrossSelfFertilization                   0.565378
# ExpressionofEmotionManAnimals                   0.701498
# FormationVegetableMould                         0.754896
# FoundationsOriginofSpecies                      0.656304
# GeologicalObservationsSouthAmerica              0.674519
# InsectivorousPlants                             0.748059
# LifeandLettersVol1                              0.634634
# LifeandLettersVol2                              0.599234
# MonographCirripedia                             0.642731
# MonographCirripediaVol2                         0.653343
# MovementClimbingPlants                          0.773696
# OriginofSpecies                                 0.666128
# PowerMovementPlants                             1.000000
# VariationPlantsAnimalsDomestication             0.692700
# VolcanicIslands                                 0.677054
# VoyageBeagle                                    0.788279
#
#                                      VariationPlantsAnimalsDomestication  \
# Autobiography                                                   0.696499
# CoralReefs                                                      0.719714
# DescentofMan                                                    0.858421
# DifferentFormsofFlowers                                         0.699729
# EffectsCrossSelfFertilization                                   0.575229
# ExpressionofEmotionManAnimals                                   0.815230
# FormationVegetableMould                                         0.742557
# FoundationsOriginofSpecies                                      0.857159
# GeologicalObservationsSouthAmerica                              0.765187
# InsectivorousPlants                                             0.649481
# LifeandLettersVol1                                              0.708267
# LifeandLettersVol2                                              0.698020
# MonographCirripedia                                             0.740972
# MonographCirripediaVol2                                         0.767674
# MovementClimbingPlants                                          0.708203
# OriginofSpecies                                                 0.876347
# PowerMovementPlants                                             0.692700
# VariationPlantsAnimalsDomestication                             1.000000
# VolcanicIslands                                                 0.786560
# VoyageBeagle                                                    0.827342
#
#                                      VolcanicIslands  VoyageBeagle
# Autobiography                               0.655968      0.830519
# CoralReefs                                  0.807210      0.797567
# DescentofMan                                0.739277      0.791111
# DifferentFormsofFlowers                     0.618968      0.646935
# EffectsCrossSelfFertilization               0.480384      0.538932
# ExpressionofEmotionManAnimals               0.754096      0.826773
# FormationVegetableMould                     0.761638      0.836069
# FoundationsOriginofSpecies                  0.740283      0.794574
# GeologicalObservationsSouthAmerica          0.899808      0.843135
# InsectivorousPlants                         0.640564      0.738004
# LifeandLettersVol1                          0.658068      0.813076
# LifeandLettersVol2                          0.648714      0.755466
# MonographCirripedia                         0.715577      0.726851
# MonographCirripediaVol2                     0.747256      0.744307
# MovementClimbingPlants                      0.672252      0.751101
# OriginofSpecies                             0.777222      0.817594
# PowerMovementPlants                         0.677054      0.788279
# VariationPlantsAnimalsDomestication         0.786560      0.827342
# VolcanicIslands                             1.000000      0.848263
# VoyageBeagle                                0.848263      1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import libraries
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df["OriginofSpecies"]

# Sort by ascending scores
v_sorted = v.sort_values()

# Plot this data has a horizontal bar plot
v_sorted.plot.barh();

# Modify the axes labels and plot title for a better readability
plt.xlabel("TF-IDF Score")
plt.ylabel("Books")
plt.title("Similarity with Origin of Species")
# Out:
# Text(0.5, 1.0, 'Similarity with Origin of Species')

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Heatmap
fig = plt.figure(figsize=(10,10))
plt.imshow(sim_df)
plt.title("Similarity Heatmap")
plt.show()

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sims, method="ward");

# Display this result as a horizontal dendrogram
hierarchy.dendrogram(Z);

# %%
Z
# Out:
# array([[10.        , 11.        ,  0.13864826,  2.        ],
#        [ 8.        , 18.        ,  0.15918504,  2.        ],
#        [12.        , 13.        ,  0.17247519,  2.        ],
#        [ 7.        , 15.        ,  0.18030094,  2.        ],
#        [17.        , 23.        ,  0.25194489,  3.        ],
#        [ 2.        ,  5.        ,  0.30166539,  2.        ],
#        [ 0.        , 20.        ,  0.32579973,  3.        ],
#        [14.        , 16.        ,  0.34766302,  2.        ],
#        [24.        , 25.        ,  0.39662484,  5.        ],
#        [ 1.        , 21.        ,  0.41913142,  3.        ],
#        [ 6.        , 19.        ,  0.44043699,  2.        ],
#        [ 9.        , 27.        ,  0.47705751,  3.        ],
#        [ 3.        ,  4.        ,  0.59217294,  2.        ],
#        [29.        , 30.        ,  0.59316104,  5.        ],
#        [28.        , 33.        ,  0.82155996, 10.        ],
#        [22.        , 34.        ,  0.90117443, 12.        ],
#        [31.        , 35.        ,  1.10441459, 15.        ],
#        [26.        , 36.        ,  1.31834549, 18.        ],
#        [32.        , 37.        ,  1.69645926, 20.        ]])
